# %%
import pandas as pd

# %%
df_cin = pd.read_csv("data/countyinflow1920.csv")
df_cin
# Out:
#        y2_statefips  y2_countyfips  y1_statefips  y1_countyfips y1_state  \
# 0                 1              1            96              0       AL
# 1                 1              1            97              0       AL
# 2                 1              1            97              1       AL
# 3                 1              1            97              3       AL
# 4                 1              1            98              0       AL
# ...             ...            ...           ...            ...      ...
# 87547            56             45            59              0       DS
# 87548            56             45            59              1       DS
# 87549            56             45            59              3       DS
# 87550            56             45            59              5       DS
# 87551            56             45            59              7       DS
#
#                                         y1_countyname    n1    n2     agi
# ...

# %%
df_cout = pd.read_csv("data/countyoutflow1920.csv")
df_cout
# Out:
#        y1_statefips  y1_countyfips  y2_statefips  y2_countyfips y2_state  \
# 0                 1              1            96              0       AL
# 1                 1              1            97              0       AL
# 2                 1              1            97              1       AL
# 3                 1              1            97              3       AL
# 4                 1              1            98              0       AL
# ...             ...            ...           ...            ...      ...
# 87320            56             45            59              0       DS
# 87321            56             45            59              1       DS
# 87322            56             45            59              3       DS
# 87323            56             45            59              5       DS
# 87324            56             45            59              7       DS
#
#                                         y2_countyname    n1    n2     agi
# ...

# %%
df_sin = pd.read_csv("data/stateinflow1920.csv")
df_sin
# Out:
#       y2_statefips  y1_statefips y1_state                      y1_state_name  \
# 0                1            96       AL  AL Total Migration-US and Foreign
# 1                1            97       AL              AL Total Migration-US
# 2                1            98       AL         AL Total Migration-Foreign
# 3                1            97       AL      AL Total Migration-Same State
# 4                1             1       AL                    AL Non-migrants
# ...            ...           ...      ...                                ...
# 2850            56            50       VT                            Vermont
# 2851            56            33       NH                      New Hampshire
# 2852            56            10       DE                           Delaware
# 2853            56            11       DC               District Of Columbia
# 2854            56            44       RI                       Rhode Island
#
#            n1       n2        AGI
# ...

# %%
df_sout = pd.read_csv("data/stateoutflow1920.csv")
df_sout
# Out:
#       y1_statefips  y2_statefips y2_state                      y2_state_name  \
# 0                1            96       AL  AL Total Migration-US and Foreign
# 1                1            97       AL              AL Total Migration-US
# 2                1            98       AL         AL Total Migration-Foreign
# 3                1            97       AL      AL Total Migration-Same State
# 4                1             1       AL                    AL Non-migrants
# ...            ...           ...      ...                                ...
# 2850            56             9       CT                        Connecticut
# 2851            56            50       VT                            Vermont
# 2852            56            10       DE                           Delaware
# 2853            56            44       RI                       Rhode Island
# 2854            56            11       DC               District Of Columbia
#
#            n1       n2        AGI
# ...
